# %%
# Dependencies
import tweepy
import json
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# Twitter API Keys
consumer_key = "Ed4RNulN1lp7AbOooHa9STCoU"
consumer_secret = "P7cUJlmJZq0VaCY0Jg7COliwQqzK0qYEyUF9Y0idx4ujb3ZlW5"
access_token = "839621358724198402-dzdOsx2WWHrSuBwyNUiqSEnTivHozAZ"
access_token_secret = "dCZ80uNRbFDjxdU2EckmNiSckdoATach6Q8zb7YYYE5ER"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
#This analysis helps you to find the "locations" that Twitter has trending topic information for. 
#The response is an array of "locations" that encode the location's WOEID 
#A WOEID is a Yahoo:" Where On Earth ID"
#comment out #api.trends_available() to see the results



#api.trends_available()

# %%
#To find the closet trendy hashtags in any city, type the lon & lat, example below Lon&Lat for San Francisco
api.trends_closest(37.77, -122.41)

#Analysis and how to find the closet trends:
#Go to http://woeid.rosselliot.co.nz/ 
#Type in "Search Place": San Francisco
#Then find the woeid#: 2487956 to know where the most hastags trends in San Francisco

#This analysis helps you know where exactly the most active tags/accounts in City in case you need to start a promotion or target consumers or for political reasons
# Out:
# [{'name': 'San Francisco',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2487956',
#   'parentid': 23424977,
#   'country': 'United States',
#   'woeid': 2487956,
#   'countryCode': 'US'}]

# %%
#To see What is the most active hashtags in San Francisco, you can type the code below + the woeid
api.trends_place(2487956)

#Analysis:
# Trends name shows the most active tags in San Francisco by url, query, tweet_volume
# Out:
# [{'trends': [{'name': '#MK11',
#     'url': 'http://twitter.com/search?q=%23MK11',
#     'promoted_content': None,
#     'query': '%23MK11',
#     'tweet_volume': 46448},
#    {'name': 'Mary Oliver',
#     'url': 'http://twitter.com/search?q=%22Mary+Oliver%22',
#     'promoted_content': None,
#     'query': '%22Mary+Oliver%22',
#     'tweet_volume': 53565},
#    {'name': 'Mortal Kombat',
#     'url': 'http://twitter.com/search?q=%22Mortal+Kombat%22',
#     'promoted_content': None,
#     'query': '%22Mortal+Kombat%22',
#     'tweet_volume': 34937},
#    {'name': 'Pelosi',
#     'url': 'http://twitter.com/search?q=Pelosi',
#     'promoted_content': None,
#     'query': 'Pelosi',
#     'tweet_volume': 929110},
#    {'name': 'Betty White',
#     'url': 'http://twitter.com/search?q=%22Betty+White%22',
#     'promoted_content': None,
#     'query': '%22Betty+White%22',
#     'tweet_volume': 81508},
#    {'name': 'Michael Cohen',
#     'url': 'http://twitter.com/search?q=%22Michael+Cohen%22',
#     'promoted_content': None,
#     'query': '%22Michael+Cohen%22',
#     'tweet_volume': 101663},
#    {'name': '#ThursdayThoughts',
#     'url': 'http://twitter.com/search?q=%23ThursdayThoughts',
#     'promoted_content': None,
#     'query': '%23ThursdayThoughts',
#     'tweet_volume': 111730},
#    {'name': '#earthquake',
#     'url': 'http://twitter.com/search?q=%23earthquake',
#     'promoted_content': None,
#     'query': '%23earthquake',
#     'tweet_volume': 10413},
#    {'name': 'Slack',
#     'url': 'http://twitter.com/search?q=Slack',
#     'promoted_content': None,
#     'query': 'Slack',
#     'tweet_volume': 39289},
#    {'name': '#WheresMitch',
#     'url': 'http://twitter.com/search?q=%23WheresMitch',
#     'promoted_content': None,
#     'query': '%23WheresMitch',
#     'tweet_volume': 342217},
#    {'name': '#MortalKombat11',
#     'url': 'http://twitter.com/search?q=%23MortalKombat11',
#     'promoted_content': None,
#     'query': '%23MortalKombat11',
#     'tweet_volume': 18443},
#    {'name': 'John Wick',
#     'url': 'http://twitter.com/search?q=%22John+Wick%22',
#     'promoted_content': None,
#     'query': '%22John+Wick%22',
#     'tweet_volume': 78511},
#    {'name': 'Afghanistan',
#     'url': 'http://twitter.com/search?q=Afghanistan',
#     'promoted_content': None,
#     'query': 'Afghanistan',
#     'tweet_volume': 130096},
#    {'name': 'Laquan McDonald',
#     'url': 'http://twitter.com/search?q=%22Laquan+McDonald%22',
#     'promoted_content': None,
#     'query': '%22Laquan+McDonald%22',
#     'tweet_volume': None},
#    {'name': 'Adam Ottavino',
#     'url': 'http://twitter.com/search?q=%22Adam+Ottavino%22',
#     'promoted_content': None,
#     'query': '%22Adam+Ottavino%22',
#     'tweet_volume': None},
#    {'name': 'CODEL',
#     'url': 'http://twitter.com/search?q=CODEL',
#     'promoted_content': None,
#     'query': 'CODEL',
#     'tweet_volume': 19888},
#    {'name': 'Prince Philip',
#     'url': 'http://twitter.com/search?q=%22Prince+Philip%22',
#     'promoted_content': None,
#     'query': '%22Prince+Philip%22',
#     'tweet_volume': 11543},
#    {'name': 'Vampire Weekend',
#     'url': 'http://twitter.com/search?q=%22Vampire+Weekend%22',
#     'promoted_content': None,
#     'query': '%22Vampire+Weekend%22',
#     'tweet_volume': None},
#    {'name': 'Zulily',
#     'url': 'http://twitter.com/search?q=Zulily',
#     'promoted_content': None,
#     'query': 'Zulily',
#     'tweet_volume': None},
#    {'name': 'Brussels',
#     'url': 'http://twitter.com/search?q=Brussels',
#     'promoted_content': None,
#     'query': 'Brussels',
#     'tweet_volume': 55025},
#    {'name': 'Jack Dorsey',
#     'url': 'http://twitter.com/search?q=%22Jack+Dorsey%22',
#     'promoted_content': None,
#     'query': '%22Jack+Dorsey%22',
#     'tweet_volume': None},
#    {'name': 'Sonya Blade',
#     'url': 'http://twitter.com/search?q=%22Sonya+Blade%22',
#     'promoted_content': None,
#     'query': '%22Sonya+Blade%22',
#     'tweet_volume': None},
#    {'name': '3 Chicago',
#     'url': 'http://twitter.com/search?q=%223+Chicago%22',
#     'promoted_content': None,
#     'query': '%223+Chicago%22',
#     'tweet_volume': None},
#    {'name': 'Winter Storm Watch',
#     'url': 'http://twitter.com/search?q=%22Winter+Storm+Watch%22',
#     'promoted_content': None,
#     'query': '%22Winter+Storm+Watch%22',
#     'tweet_volume': None},
#    {'name': 'Canelo vs Jacobs',
#     'url': 'http://twitter.com/search?q=%22Canelo+vs+Jacobs%22',
#     'promoted_content': None,
#     'query': '%22Canelo+vs+Jacobs%22',
#     'tweet_volume': None},
#    {'name': 'MK 11',
#     'url': 'http://twitter.com/search?q=%22MK+11%22',
#     'promoted_content': None,
#     'query': '%22MK+11%22',
#     'tweet_volume': None},
#    {'name': 'Ronda Rousey',
#     'url': 'http://twitter.com/search?q=%22Ronda+Rousey%22',
#     'promoted_content': None,
#     'query': '%22Ronda+Rousey%22',
#     'tweet_volume': None},
#    {'name': 'James Blake',
#     'url': 'http://twitter.com/search?q=%22James+Blake%22',
#     'promoted_content': None,
#     'query': '%22James+Blake%22',
#     'tweet_volume': None},
#    {'name': 'Victor Rask',
#     'url': 'http://twitter.com/search?q=%22Victor+Rask%22',
#     'promoted_content': None,
#     'query': '%22Victor+Rask%22',
#     'tweet_volume': None},
#    {'name': 'Skarlet',
#     'url': 'http://twitter.com/search?q=Skarlet',
#     'promoted_content': None,
#     'query': 'Skarlet',
#     'tweet_volume': None},
#    {'name': 'Sonny Gray',
#     'url': 'http://twitter.com/search?q=%22Sonny+Gray%22',
#     'promoted_content': None,
#     'query': '%22Sonny+Gray%22',
#     'tweet_volume': None},
#    {'name': 'Nino',
#     'url': 'http://twitter.com/search?q=Nino',
#     'promoted_content': None,
#     'query': 'Nino',
#     'tweet_volume': 99371},
#    {'name': 'Wild Geese',
#     'url': 'http://twitter.com/search?q=%22Wild+Geese%22',
#     'promoted_content': None,
#     'query': '%22Wild+Geese%22',
#     'tweet_volume': None},
#    {'name': 'The Yankees',
#     'url': 'http://twitter.com/search?q=%22The+Yankees%22',
#     'promoted_content': None,
#     'query': '%22The+Yankees%22',
#     'tweet_volume': 11150},
#    {'name': 'Sounders',
#     'url': 'http://twitter.com/search?q=Sounders',
#     'promoted_content': None,
#     'query': 'Sounders',
#     'tweet_volume': None},
#    {'name': 'Michelle Obama',
#     'url': 'http://twitter.com/search?q=%22Michelle+Obama%22',
#     'promoted_content': None,
#     'query': '%22Michelle+Obama%22',
#     'tweet_volume': 40133},
#    {'name': 'Geras',
#     'url': 'http://twitter.com/search?q=Geras',
#     'promoted_content': None,
#     'query': 'Geras',
#     'tweet_volume': None},
#    {'name': 'Luke Kornet',
#     'url': 'http://twitter.com/search?q=%22Luke+Kornet%22',
#     'promoted_content': None,
#     'query': '%22Luke+Kornet%22',
#     'tweet_volume': None},
#    {'name': 'Paxton Lynch',
#     'url': 'http://twitter.com/search?q=%22Paxton+Lynch%22',
#     'promoted_content': None,
#     'query': '%22Paxton+Lynch%22',
#     'tweet_volume': None},
#    {'name': '#JohnWick3',
#     'url': 'http://twitter.com/search?q=%23JohnWick3',
#     'promoted_content': None,
#     'query': '%23JohnWick3',
#     'tweet_volume': 60136},
#    {'name': '#CaneloJacobs',
#     'url': 'http://twitter.com/search?q=%23CaneloJacobs',
#     'promoted_content': None,
#     'query': '%23CaneloJacobs',
#     'tweet_volume': None},
#    {'name': '#RejectedWeddingVows',
#     'url': 'http://twitter.com/search?q=%23RejectedWeddingVows',
#     'promoted_content': None,
#     'query': '%23RejectedWeddingVows',
#     'tweet_volume': None},
#    {'name': '#TakingMyShot',
#     'url': 'http://twitter.com/search?q=%23TakingMyShot',
#     'promoted_content': None,
#     'query': '%23TakingMyShot',
#     'tweet_volume': None},
#    {'name': '#Ham4PR',
#     'url': 'http://twitter.com/search?q=%23Ham4PR',
#     'promoted_content': None,
#     'query': '%23Ham4PR',
#     'tweet_volume': None},
#    {'name': '#AdviceFromMyGrandma',
#     'url': 'http://twitter.com/search?q=%23AdviceFromMyGrandma',
#     'promoted_content': None,
#     'query': '%23AdviceFromMyGrandma',
#     'tweet_volume': None},
#    {'name': '#RIPMaryOliver',
#     'url': 'http://twitter.com/search?q=%23RIPMaryOliver',
#     'promoted_content': None,
#     'query': '%23RIPMaryOliver',
#     'tweet_volume': None},
#    {'name': '#GetToKnowYourCustomersDay',
#     'url': 'http://twitter.com/search?q=%23GetToKnowYourCustomersDay',
#     'promoted_content': None,
#     'query': '%23GetToKnowYourCustomersDay',
#     'tweet_volume': None},
#    {'name': '#SOTForum',
#     'url': 'http://twitter.com/search?q=%23SOTForum',
#     'promoted_content': None,
#     'query': '%23SOTForum',
#     'tweet_volume': None},
#    {'name': '#MPATUO',
#     'url': 'http://twitter.com/search?q=%23MPATUO',
#     'promoted_content': None,
#     'query': '%23MPATUO',
#     'tweet_volume': None},
#    {'name': '#HaveACokeAndA',
#     'url': 'http://twitter.com/search?q=%23HaveACokeAndA',
#     'promoted_content': None,
#     'query': '%23HaveACokeAndA',
#     'tweet_volume': None}],
#   'as_of': '2019-01-17T22:04:22Z',
#   'created_at': '2019-01-17T21:58:47Z',
#   'locations': [{'name': 'San Francisco', 'woeid': 2487956}]}]

# %%
#loop inside the most active tags by tweet volume
# Out:
#   File "<ipython-input-23-e6e54627fee7>", line 1
#     for tag in trends[{tweet_volume}];
#                                      ^
# SyntaxError: invalid syntax

# %%
#To analyse the length of time of hastags activity
# let's consider the top 
target_tags = ["#MAGA", "#10YearChallenge", "#John Wick", "#earthquake"]
time_between_tweets = []

# Loop through each hashtag
for tag in target_tags: #bigdata
    
    # Create array to record all date-times of tweets
    tweet_times = []

    # Get 100 tweets on targetted tag
    public_tweets = api.search(tag, rpp=100)
    print(tag)

    # Loop through all tweets
    for tweet in public_tweets["statuses"]:

        # Store all tweet times into the array
        tweet_times.append(tweet["created_at"])
    
    # Convert all tweet times into datetime objects
    tweet_time_objects = []

    # Add each datetime object into the array
    for x in range(len(tweet_times)):
        tweet_datetime = datetime.strptime(tweet_times[x], "%a %b %d %H:%M:%S %z %Y")
        tweet_time_objects.append(tweet_datetime)

    # Calculate the time between tweets
    time_in_between = []

    # Calculate the time in between each tweet
    for x in range(len(tweet_time_objects)-1):
        secs_apart = ((tweet_time_objects[x] - tweet_time_objects[x+1]).seconds) 
        time_in_between.append(secs_apart)

    # Seconds Between Tweets
    print("Avg. Seconds Between Tweets: %s" % np.mean(time_in_between))
    print("")
# Out:
# #MAGA
# Avg. Seconds Between Tweets: 0.35714285714285715
#
# #10YearChallenge
# Avg. Seconds Between Tweets: 0.15384615384615385
#
# #John Wick
# Avg. Seconds Between Tweets: 5099.0
#
# #earthquake
# Avg. Seconds Between Tweets: 7.214285714285714

# %%
#Analysis of the activity above:
#The most active #hastag between the 4 most trending and popular hastags("#MAGA","#10YearChallenge","#John Wick","#earthquake")
#is #10YearChallenge: every 15 seconds, there is someone tweeting and using this hastag

# %%
api.trends_place(2487956)
# Out:
# [{'trends': [{'name': '#MK11',
#     'url': 'http://twitter.com/search?q=%23MK11',
#     'promoted_content': None,
#     'query': '%23MK11',
#     'tweet_volume': 45962},
#    {'name': 'Mary Oliver',
#     'url': 'http://twitter.com/search?q=%22Mary+Oliver%22',
#     'promoted_content': None,
#     'query': '%22Mary+Oliver%22',
#     'tweet_volume': 52977},
#    {'name': 'Mortal Kombat',
#     'url': 'http://twitter.com/search?q=%22Mortal+Kombat%22',
#     'promoted_content': None,
#     'query': '%22Mortal+Kombat%22',
#     'tweet_volume': 34492},
#    {'name': 'Pelosi',
#     'url': 'http://twitter.com/search?q=Pelosi',
#     'promoted_content': None,
#     'query': 'Pelosi',
#     'tweet_volume': 919730},
#    {'name': 'Betty White',
#     'url': 'http://twitter.com/search?q=%22Betty+White%22',
#     'promoted_content': None,
#     'query': '%22Betty+White%22',
#     'tweet_volume': 81101},
#    {'name': 'Michael Cohen',
#     'url': 'http://twitter.com/search?q=%22Michael+Cohen%22',
#     'promoted_content': None,
#     'query': '%22Michael+Cohen%22',
#     'tweet_volume': 101196},
#    {'name': '#ThursdayThoughts',
#     'url': 'http://twitter.com/search?q=%23ThursdayThoughts',
#     'promoted_content': None,
#     'query': '%23ThursdayThoughts',
#     'tweet_volume': 111408},
#    {'name': '#earthquake',
#     'url': 'http://twitter.com/search?q=%23earthquake',
#     'promoted_content': None,
#     'query': '%23earthquake',
#     'tweet_volume': 10372},
#    {'name': 'Slack',
#     'url': 'http://twitter.com/search?q=Slack',
#     'promoted_content': None,
#     'query': 'Slack',
#     'tweet_volume': 39207},
#    {'name': '#WheresMitch',
#     'url': 'http://twitter.com/search?q=%23WheresMitch',
#     'promoted_content': None,
#     'query': '%23WheresMitch',
#     'tweet_volume': 341272},
#    {'name': '#MortalKombat11',
#     'url': 'http://twitter.com/search?q=%23MortalKombat11',
#     'promoted_content': None,
#     'query': '%23MortalKombat11',
#     'tweet_volume': 18241},
#    {'name': 'John Wick',
#     'url': 'http://twitter.com/search?q=%22John+Wick%22',
#     'promoted_content': None,
#     'query': '%22John+Wick%22',
#     'tweet_volume': 77815},
#    {'name': 'Afghanistan',
#     'url': 'http://twitter.com/search?q=Afghanistan',
#     'promoted_content': None,
#     'query': 'Afghanistan',
#     'tweet_volume': 127454},
#    {'name': 'Laquan McDonald',
#     'url': 'http://twitter.com/search?q=%22Laquan+McDonald%22',
#     'promoted_content': None,
#     'query': '%22Laquan+McDonald%22',
#     'tweet_volume': None},
#    {'name': 'Adam Ottavino',
#     'url': 'http://twitter.com/search?q=%22Adam+Ottavino%22',
#     'promoted_content': None,
#     'query': '%22Adam+Ottavino%22',
#     'tweet_volume': None},
#    {'name': 'CODEL',
#     'url': 'http://twitter.com/search?q=CODEL',
#     'promoted_content': None,
#     'query': 'CODEL',
#     'tweet_volume': 19366},
#    {'name': 'Prince Philip',
#     'url': 'http://twitter.com/search?q=%22Prince+Philip%22',
#     'promoted_content': None,
#     'query': '%22Prince+Philip%22',
#     'tweet_volume': 11382},
#    {'name': 'Brussels',
#     'url': 'http://twitter.com/search?q=Brussels',
#     'promoted_content': None,
#     'query': 'Brussels',
#     'tweet_volume': 54062},
#    {'name': 'Zulily',
#     'url': 'http://twitter.com/search?q=Zulily',
#     'promoted_content': None,
#     'query': 'Zulily',
#     'tweet_volume': None},
#    {'name': 'Vampire Weekend',
#     'url': 'http://twitter.com/search?q=%22Vampire+Weekend%22',
#     'promoted_content': None,
#     'query': '%22Vampire+Weekend%22',
#     'tweet_volume': None},
#    {'name': 'Sonya Blade',
#     'url': 'http://twitter.com/search?q=%22Sonya+Blade%22',
#     'promoted_content': None,
#     'query': '%22Sonya+Blade%22',
#     'tweet_volume': None},
#    {'name': '3 Chicago',
#     'url': 'http://twitter.com/search?q=%223+Chicago%22',
#     'promoted_content': None,
#     'query': '%223+Chicago%22',
#     'tweet_volume': None},
#    {'name': 'Jack Dorsey',
#     'url': 'http://twitter.com/search?q=%22Jack+Dorsey%22',
#     'promoted_content': None,
#     'query': '%22Jack+Dorsey%22',
#     'tweet_volume': None},
#    {'name': 'Winter Storm Watch',
#     'url': 'http://twitter.com/search?q=%22Winter+Storm+Watch%22',
#     'promoted_content': None,
#     'query': '%22Winter+Storm+Watch%22',
#     'tweet_volume': None},
#    {'name': 'Canelo vs Jacobs',
#     'url': 'http://twitter.com/search?q=%22Canelo+vs+Jacobs%22',
#     'promoted_content': None,
#     'query': '%22Canelo+vs+Jacobs%22',
#     'tweet_volume': None},
#    {'name': 'Ronda Rousey',
#     'url': 'http://twitter.com/search?q=%22Ronda+Rousey%22',
#     'promoted_content': None,
#     'query': '%22Ronda+Rousey%22',
#     'tweet_volume': None},
#    {'name': 'James Blake',
#     'url': 'http://twitter.com/search?q=%22James+Blake%22',
#     'promoted_content': None,
#     'query': '%22James+Blake%22',
#     'tweet_volume': None},
#    {'name': 'MK 11',
#     'url': 'http://twitter.com/search?q=%22MK+11%22',
#     'promoted_content': None,
#     'query': '%22MK+11%22',
#     'tweet_volume': None},
#    {'name': 'Victor Rask',
#     'url': 'http://twitter.com/search?q=%22Victor+Rask%22',
#     'promoted_content': None,
#     'query': '%22Victor+Rask%22',
#     'tweet_volume': None},
#    {'name': 'Skarlet',
#     'url': 'http://twitter.com/search?q=Skarlet',
#     'promoted_content': None,
#     'query': 'Skarlet',
#     'tweet_volume': None},
#    {'name': 'The Yankees',
#     'url': 'http://twitter.com/search?q=%22The+Yankees%22',
#     'promoted_content': None,
#     'query': '%22The+Yankees%22',
#     'tweet_volume': 11049},
#    {'name': 'Sonny Gray',
#     'url': 'http://twitter.com/search?q=%22Sonny+Gray%22',
#     'promoted_content': None,
#     'query': '%22Sonny+Gray%22',
#     'tweet_volume': None},
#    {'name': 'Wild Geese',
#     'url': 'http://twitter.com/search?q=%22Wild+Geese%22',
#     'promoted_content': None,
#     'query': '%22Wild+Geese%22',
#     'tweet_volume': None},
#    {'name': 'Nino',
#     'url': 'http://twitter.com/search?q=Nino',
#     'promoted_content': None,
#     'query': 'Nino',
#     'tweet_volume': 98893},
#    {'name': 'Luke Kornet',
#     'url': 'http://twitter.com/search?q=%22Luke+Kornet%22',
#     'promoted_content': None,
#     'query': '%22Luke+Kornet%22',
#     'tweet_volume': None},
#    {'name': 'Michelle Obama',
#     'url': 'http://twitter.com/search?q=%22Michelle+Obama%22',
#     'promoted_content': None,
#     'query': '%22Michelle+Obama%22',
#     'tweet_volume': 39762},
#    {'name': 'Sounders',
#     'url': 'http://twitter.com/search?q=Sounders',
#     'promoted_content': None,
#     'query': 'Sounders',
#     'tweet_volume': None},
#    {'name': 'Geras',
#     'url': 'http://twitter.com/search?q=Geras',
#     'promoted_content': None,
#     'query': 'Geras',
#     'tweet_volume': None},
#    {'name': 'Dembele',
#     'url': 'http://twitter.com/search?q=Dembele',
#     'promoted_content': None,
#     'query': 'Dembele',
#     'tweet_volume': 38033},
#    {'name': '#JohnWick3',
#     'url': 'http://twitter.com/search?q=%23JohnWick3',
#     'promoted_content': None,
#     'query': '%23JohnWick3',
#     'tweet_volume': 59686},
#    {'name': '#CaneloJacobs',
#     'url': 'http://twitter.com/search?q=%23CaneloJacobs',
#     'promoted_content': None,
#     'query': '%23CaneloJacobs',
#     'tweet_volume': None},
#    {'name': '#RejectedWeddingVows',
#     'url': 'http://twitter.com/search?q=%23RejectedWeddingVows',
#     'promoted_content': None,
#     'query': '%23RejectedWeddingVows',
#     'tweet_volume': None},
#    {'name': '#TakingMyShot',
#     'url': 'http://twitter.com/search?q=%23TakingMyShot',
#     'promoted_content': None,
#     'query': '%23TakingMyShot',
#     'tweet_volume': None},
#    {'name': '#Ham4PR',
#     'url': 'http://twitter.com/search?q=%23Ham4PR',
#     'promoted_content': None,
#     'query': '%23Ham4PR',
#     'tweet_volume': None},
#    {'name': '#AdviceFromMyGrandma',
#     'url': 'http://twitter.com/search?q=%23AdviceFromMyGrandma',
#     'promoted_content': None,
#     'query': '%23AdviceFromMyGrandma',
#     'tweet_volume': None},
#    {'name': '#GetToKnowYourCustomersDay',
#     'url': 'http://twitter.com/search?q=%23GetToKnowYourCustomersDay',
#     'promoted_content': None,
#     'query': '%23GetToKnowYourCustomersDay',
#     'tweet_volume': None},
#    {'name': '#SOTForum',
#     'url': 'http://twitter.com/search?q=%23SOTForum',
#     'promoted_content': None,
#     'query': '%23SOTForum',
#     'tweet_volume': None},
#    {'name': '#MPATUO',
#     'url': 'http://twitter.com/search?q=%23MPATUO',
#     'promoted_content': None,
#     'query': '%23MPATUO',
#     'tweet_volume': None},
#    {'name': '#RIPMaryOliver',
#     'url': 'http://twitter.com/search?q=%23RIPMaryOliver',
#     'promoted_content': None,
#     'query': '%23RIPMaryOliver',
#     'tweet_volume': None},
#    {'name': '#HaveACokeAndA',
#     'url': 'http://twitter.com/search?q=%23HaveACokeAndA',
#     'promoted_content': None,
#     'query': '%23HaveACokeAndA',
#     'tweet_volume': None}],
#   'as_of': '2019-01-17T22:02:26Z',
#   'created_at': '2019-01-17T21:53:51Z',
#   'locations': [{'name': 'San Francisco', 'woeid': 2487956}]}]

# %%
api.trends_closest(40.71, -74.00)
# Out:
# [{'name': 'New York',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2459115',
#   'parentid': 23424977,
#   'country': 'United States',
#   'woeid': 2459115,
#   'countryCode': 'US'}]

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-9f509d85bf6a> in <module>()
#       1 # Import and Initialize Sentiment Analyzer
# ----> 2 from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#       3 analyzer = SentimentIntensityAnalyzer()
#
# ModuleNotFoundError: No module named 'vaderSentiment'

# %%
# Target User Accounts
target_user = ("@DalaiLama", "@realdonaldtrump", "@katyperry")

# %%
# Loop through each user
for user in target_user:

    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []

    # Loop through 10 pages of tweets (total 200 tweets)
    for x in range(10):

        # Get all tweets from home feed
        public_tweets = api.user_timeline(user)

        # Loop through all tweets
        for tweet in public_tweets:

            # Run Vader Analysis on each tweet
            compound = analyzer.polarity_scores(tweet["text"])["compound"]
            pos = analyzer.polarity_scores(tweet["text"])["pos"]
            neu = analyzer.polarity_scores(tweet["text"])["neu"]
            neg = analyzer.polarity_scores(tweet["text"])["neg"]

            # Add each value to the appropriate array
            compound_list.append(compound)
            positive_list.append(pos)
            negative_list.append(neg)
            neutral_list.append(neu)

    # Print the Averages
    print("")
    print("User: %s" % user)
    print("Compound: %s" % np.mean(positive_list))
    print("Positive: %s" % np.mean(positive_list))
    print("Neutral: %s" % np.mean(neutral_list))
    print("Negative: %s" % np.mean(negative_list))
# Out:
# User: @DalaiLama
# Compound: 0.27165
# Positive: 0.27165
# Neutral: 0.67255
# Negative: 0.05585
#
# User: @realdonaldtrump
# Compound: 0.06789999999999999
# Positive: 0.06789999999999999
# Neutral: 0.81255
# Negative: 0.1195
#
# User: @katyperry
# Compound: 0.18045000000000003
# Positive: 0.18045000000000003
# Neutral: 0.8081499999999999
# Negative: 0.01135

# %%
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(1,6):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user, page = x)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        
        # Add sentiments for each tweet into an array
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweet Number": counter})
        
        # Add to counter 
        counter = counter + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a127b0211730> in <module>()
#      18
#      19         # Run Vader Analysis on each tweet
# ---> 20         compound = analyzer.polarity_scores(tweet["text"])["compound"]
#      21         pos = analyzer.polarity_scores(tweet["text"])["pos"]
#      22         neu = analyzer.polarity_scores(tweet["text"])["neu"]
#
# NameError: name 'analyzer' is not defined

# %%
# Convert sentiments to DataFrame
sentiments_pd = pd.DataFrame.from_dict(sentiments)
sentiments_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0       0.0  Thu Dec 21 08:42:08 +0000 2017       1.0      0.0       0.0
# 1       0.0  Thu Dec 21 07:42:07 +0000 2017       1.0      0.0       0.0
# 2       0.0  Thu Dec 21 06:42:07 +0000 2017       1.0      0.0       0.0
# 3       0.0  Thu Dec 21 05:42:07 +0000 2017       1.0      0.0       0.0
# 4       0.0  Thu Dec 21 04:42:06 +0000 2017       1.0      0.0       0.0
#
#    Tweet Number
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5

# %%
 # Create plot
plt.plot(np.arange(len(sentiments_pd["Compound"])),
         sentiments_pd["Compound"], marker="o", linewidth=0.5,
         alpha=0.8)

# # Incorporate the other graph properties
plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweet Number")
plt.show()

# %%
# List to hold sentiment
compound_list = []
positive_list = []
negative_list = []
neutral_list = []

# Grab 25 tweets
public_tweets = api.search(target_user, count=25, result_type="recent")

# Loop through all tweets
for tweet in public_tweets["statuses"]:

    # Run Vader Analysis on each tweet
    compound = analyzer.polarity_scores(tweet["text"])["compound"]
    pos = analyzer.polarity_scores(tweet["text"])["pos"]
    neu = analyzer.polarity_scores(tweet["text"])["neu"]
    neg = analyzer.polarity_scores(tweet["text"])["neg"]

    # Add each value to the appropriate array
    compound_list.append(compound)
    positive_list.append(pos)
    negative_list.append(neg)
    neutral_list.append(neu)

# Store the Average Sentiments
sentiment = {"Compound": np.mean(compound_list),
             "Positive": np.mean(positive_list),
             "Neutral": np.mean(negative_list),
             "Negative": np.mean(neutral_list)}

# Print the Sentiments
print(sentiment)
print("")
# Out:
# {'Compound': nan, 'Positive': nan, 'Neutral': nan, 'Negative': nan}
# /Users/ahmadmer/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/ahmadmer/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# Get all tweets from home feed
public_tweets = api.user_timeline()

# Loop through all tweets
for tweet in public_tweets:

    # Utilize JSON dumps to generate a pretty-printed json
    print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 08:42:08 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "favorite_count": 1,
#     "favorited": false,
#     "geo": null,
#     "id": 943763503969656832,
#     "id_str": "943763503969656832",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "London Weather as of 08:42 AM: 50.36 F",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 07:42:07 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "favorite_count": 1,
#     "favorited": false,
#     "geo": null,
#     "id": 943748403149799425,
#     "id_str": "943748403149799425",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "London Weather as of 07:42 AM: 50 F",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 06:42:07 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943733302296539137,
#     "id_str": "943733302296539137",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "London Weather as of 06:42 AM: 49.64 F",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 05:42:07 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943718201321508864,
#     "id_str": "943718201321508864",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "London Weather as of 05:42 AM: 49.8 F",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 04:42:06 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943703100333936640,
#     "id_str": "943703100333936640",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "London Weather as of 04:42 AM: 49.59 F",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 03:42:06 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943687999270932480,
#     "id_str": "943687999270932480",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "London Weather as of 03:42 AM: 49.77 F",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:44 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 4146368896,
#                 "id_str": "4146368896",
#                 "indices": [
#                     10,
#                     25
#                 ],
#                 "name": "avery",
#                 "screen_name": "avery_norstrom"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675073063292928,
#     "id_str": "943675073063292928",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @avery_norstrom! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:44 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 4146368896,
#                 "id_str": "4146368896",
#                 "indices": [
#                     10,
#                     25
#                 ],
#                 "name": "avery",
#                 "screen_name": "avery_norstrom"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675071985475584,
#     "id_str": "943675071985475584",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @avery_norstrom! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:44 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 1126213752,
#                 "id_str": "1126213752",
#                 "indices": [
#                     10,
#                     23
#                 ],
#                 "name": "awen thornber",
#                 "screen_name": "awenthornber"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675070869733376,
#     "id_str": "943675070869733376",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @awenthornber! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:43 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 1126213752,
#                 "id_str": "1126213752",
#                 "indices": [
#                     10,
#                     23
#                 ],
#                 "name": "awen thornber",
#                 "screen_name": "awenthornber"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675069716357120,
#     "id_str": "943675069716357120",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @awenthornber! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:43 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 2797721011,
#                 "id_str": "2797721011",
#                 "indices": [
#                     10,
#                     25
#                 ],
#                 "name": "Pat Furstenberg\ud83d\udd8b\ufe0fwriting about \ud83d\udee9\ufe0fwar & \ud83d\udc36dogs",
#                 "screen_name": "PatFurstenberg"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675068239945728,
#     "id_str": "943675068239945728",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @PatFurstenberg! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:43 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 3250184953,
#                 "id_str": "3250184953",
#                 "indices": [
#                     10,
#                     23
#                 ],
#                 "name": "Joy Marie Norstrom",
#                 "screen_name": "norstrom_joy"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675066797060096,
#     "id_str": "943675066797060096",
#     "in_reply_to_screen_name": "norstrom_joy",
#     "in_reply_to_status_id": 942525036073590784,
#     "in_reply_to_status_id_str": "942525036073590784",
#     "in_reply_to_user_id": 3250184953,
#     "in_reply_to_user_id_str": "3250184953",
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @norstrom_joy! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:42 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 2873818224,
#                 "id_str": "2873818224",
#                 "indices": [
#                     10,
#                     22
#                 ],
#                 "name": "Esma Morrell",
#                 "screen_name": "EsmaMorrell"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675065245171712,
#     "id_str": "943675065245171712",
#     "in_reply_to_screen_name": "EsmaMorrell",
#     "in_reply_to_status_id": 942557877675352064,
#     "in_reply_to_status_id_str": "942557877675352064",
#     "in_reply_to_user_id": 2873818224,
#     "in_reply_to_user_id_str": "2873818224",
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @EsmaMorrell! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:42 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675064100167682,
#     "id_str": "943675064100167682",
#     "in_reply_to_screen_name": "marimarxista",
#     "in_reply_to_status_id": 942561570105712640,
#     "in_reply_to_status_id_str": "942561570105712640",
#     "in_reply_to_user_id": 1853624682,
#     "in_reply_to_user_id_str": "1853624682",
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @marimargaryen! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:42 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 479508131,
#                 "id_str": "479508131",
#                 "indices": [
#                     10,
#                     23
#                 ],
#                 "name": "SJHS",
#                 "screen_name": "SJHighSchool"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675062950883328,
#     "id_str": "943675062950883328",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @SJHighSchool! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:42 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 2418493519,
#                 "id_str": "2418493519",
#                 "indices": [
#                     10,
#                     22
#                 ],
#                 "name": "Hadley Couch",
#                 "screen_name": "venusisbutt"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675061747118080,
#     "id_str": "943675061747118080",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @venusisbutt! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:41 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 3250184953,
#                 "id_str": "3250184953",
#                 "indices": [
#                     10,
#                     23
#                 ],
#                 "name": "Joy Marie Norstrom",
#                 "screen_name": "norstrom_joy"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675060652355584,
#     "id_str": "943675060652355584",
#     "in_reply_to_screen_name": "norstrom_joy",
#     "in_reply_to_status_id": 942786731430039555,
#     "in_reply_to_status_id_str": "942786731430039555",
#     "in_reply_to_user_id": 3250184953,
#     "in_reply_to_user_id_str": "3250184953",
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @norstrom_joy! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:41 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 3250184953,
#                 "id_str": "3250184953",
#                 "indices": [
#                     10,
#                     23
#                 ],
#                 "name": "Joy Marie Norstrom",
#                 "screen_name": "norstrom_joy"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675059540959233,
#     "id_str": "943675059540959233",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @norstrom_joy! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:41 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 4146368896,
#                 "id_str": "4146368896",
#                 "indices": [
#                     10,
#                     25
#                 ],
#                 "name": "avery",
#                 "screen_name": "avery_norstrom"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675058383306752,
#     "id_str": "943675058383306752",
#     "in_reply_to_screen_name": "avery_norstrom",
#     "in_reply_to_status_id": 942855056319270912,
#     "in_reply_to_status_id_str": "942855056319270912",
#     "in_reply_to_user_id": 4146368896,
#     "in_reply_to_user_id_str": "4146368896",
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @avery_norstrom! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 21 02:50:40 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 4146368896,
#                 "id_str": "4146368896",
#                 "indices": [
#                     10,
#                     25
#                 ],
#                 "name": "avery",
#                 "screen_name": "avery_norstrom"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 943675057049444352,
#     "id_str": "943675057049444352",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">DataExercises</a>",
#     "text": "Thank you @avery_norstrom! Come again!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 08 23:38:26 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Note: This profile is intended strictly for educational purposes of working with the Twitter API. Tweets may be automated.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2,
#         "follow_request_sent": false,
#         "followers_count": 32,
#         "following": false,
#         "friends_count": 22,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 839621358724198402,
#         "id_str": "839621358724198402",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1,
#         "location": "",
#         "name": "DaDataBootcamp",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/840057542579380224/ydcUwwXV_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "DaDataBootcamp",
#         "statuses_count": 60251,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }

# %%
from __future__ import print_function
import tweepy
import json
from pymongo import MongoClient

# %%
# assuming you have mongoDB installed locally
# and a database called 'twitterdb'
MONGO_HOST= 'mongodb://localhost/twitterdb'

# %%
WORDS = ['#bigdata', '#AI', '#datascience', '#machinelearning', '#ml', '#iot']

# %%
class StreamListener(tweepy.StreamListener):    
    #This is a class provided by tweepy to access the Twitter Streaming API. 
 
    def on_connect(self):
        # Called initially to connect to the Streaming API
        print("You are now connected to the streaming API.")
 
    def on_error(self, status_code):
        # On error - if an error occurs, display the error / status code
        print('An Error has occured: ' + repr(status_code))
        return False
 
    def on_data(self, data):
        #This is the meat of the script...it connects to your mongoDB and stores the tweet
        try:
            client = MongoClient(MONGO_HOST)
            
            # Use twitterdb database. If it doesn't exist, it will be created.
            db = client.twitterdb
    
            # Decode the JSON from Twitter
            datajson = json.loads(data)
            
            #grab the 'created_at' data from the Tweet to use for display
            created_at = datajson['created_at']
 
            #print out a message to the screen that we have collected a tweet
            print("Tweet collected at " + str(created_at))
            
            #insert the data into the mongoDB into a collection called twitter_search
            #if twitter_search doesn't exist, it will be created.
            db.twitter_search.insert(datajson)
        except Exception as e:
           print(e)

# %%
#Set up the listener. The 'wait_on_rate_limit=True' is needed to help with Twitter API rate limiting.
listener = StreamListener(api=tweepy.API(wait_on_rate_limit=True)) 
streamer = tweepy.Stream(auth=auth, listener=listener)
#print("Tracking: " + str(WORDS))
streamer.filter(track=WORDS)

# %%
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.nhl_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://twitter.com/search-home'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

# %%
#Retrieve the parent divs for all articles
results = soup.find_all('li', class_='<search-input')
#<span class="u-hiddenVisually">Search query</span>
#<input id="search-home-input" class="search-input" autocomplete="off" spellcheck="false" value="" name="q" type="text" aria-autocomplete="list" aria-expanded="false" aria-owns="typeahead-dropdown-3">
#<li class="AdaptiveFiltersBar-item u-borderUserColor ">
            #/li>
    
    #<h1 class="SearchNavigation-titleText" dir="ltr">
        #curry
      #</h1>
    
   # <input class="search-input" type="text" id="search-query" placeholder="Search Twitter" name="q" autocomplete="off" spellcheck="false" aria-autocomplete="list" aria-expanded="false" aria-owns="typeahead-dropdown-4" dir="ltr" style="direction: ltr; text-align: left;">
# Loop through results to retrieve article title, header, and timestamp of article
for result in results:
    title = result.find('h1', class_='search-imput').text

    #lede = result.find('h5', class_='mixed-feed__subheader').text
print(results) 
    

#     # The time and date of article publication
#     date = result.find('time')['datetime']
    
   
#     # Slice the datetime string for the date
#     article_date = date[:10]
#     # Slice the datetime string for the time
#     time = date[11:16]
#     # Determine whether article was published in AM or PM
#     if (int(time[:2]) >= 13):
#         meridiem = 'pm'
#     else:
#         meridiem = 'am'

#     # Concatenate time string
#     time = time + meridiem
#     print('-----------------')
#     print(title)
#     print(lede)
#     print(article_date)
#     print(time)

#     # Dictionary to be inserted into MongoDB
#     post = {
#         'title': title,
#         'lede': lede,
#         'date': article_date,
#         'time published': time
#     }

    # Insert dictionary into MongoDB as a document
#     collection.insert_one(post)
# Out:
# []
